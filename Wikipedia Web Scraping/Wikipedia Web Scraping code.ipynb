# %%
from bs4 import Beautifulsoup
import request
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bs4 import Beautifulsoup
#       2 import request
#
# ImportError: cannot import name 'Beautifulsoup' from 'bs4' (C:\Users\Ali\anaconda3\Lib\site-packages\bs4\__init__.py)

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

page = requests.get(url)

soup=BeautifulSoup(page.text,'html')

# %%
soup.find('div')
# Out:
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown" title="Main menu">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Main menu</span>
# </label>
# <div class="vector-dropdown-content">
# ...

# %%
table=soup.find('table')

# %%
table
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">648,125
# </td>
# ...

# %%
table.find('th')
# Out:
# <th>Rank
# </th>

# %%
table.find_all('th')
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
worldt1=table.find_all('th')

# %%
worldt1
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
worldt2=[title.text for title in worldt1]

# %%
worldt2
# Out:
# ['Rank\n',
#  'Name\n',
#  'Industry\n',
#  'Revenue (USD millions)\n',
#  'Revenue growth\n',
#  'Employees\n',
#  'Headquarters\n']

# %%
worldt2=[title.text.strip() for title in worldt1]

# %%
worldt2
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue (USD millions)',
#  'Revenue growth',
#  'Employees',
#  'Headquarters']

# %%
import pandas as pd
df=pd.DataFrame(columns=worldt2)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
soup.find('tr')
# Out:
# <tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>

# %%
table.find('tr')
# Out:
# <tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>

# %%
table.find_all('tr')
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD millions)
#  </th>
#  <th>Revenue growth
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
#  </td>
#  <td><a href="/wiki/Retail" title="Retail">Retail</a>
#  </td>
#  <td style="text-align:center;">648,125
#  </td>
# ...

# %%
column_data=table.find_all('tr')

# %%
for row in column_data :
    row_data=row.find_all('td')
    finald=[title.text.strip() for title in row_data]
    print(finald)
# Out:
# []
# ['1', 'Walmart', 'Retail', '648,125', '6.0%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '574,785', '11.9%', '1,525,000', 'Seattle, Washington']
# ['3', 'Apple', 'Electronics industry', '383,482', '-2.8%', '161,000', 'Cupertino, California']
# ['4', 'UnitedHealth Group', 'Healthcare', '371,622', '14.6%', '440,000', 'Minnetonka, Minnesota']
# ['5', 'Berkshire Hathaway', 'Conglomerate', '364,482', '20.7%', '396,500', 'Omaha, Nebraska']
# ['6', 'CVS Health', 'Healthcare', '357,776', '10.9%', '259,500', 'Woonsocket, Rhode Island']
# ['7', 'ExxonMobil', 'Petroleum industry', '344,582', '-16.7%', '61,500', 'Spring, Texas']
# ['8', 'Alphabet', 'Technology and cloud computing', '307,394', '8.7%', '182,502', 'Mountain View, California']
# ['9', 'McKesson Corporation', 'Health', '276,711', '4.8%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '262,173', '9.9%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
for row in column_data[1:] :
    row_data=row.find_all('td')
    finald=[title.text.strip() for title in row_data]
    print(finald)
# Out:
# ['1', 'Walmart', 'Retail', '648,125', '6.0%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '574,785', '11.9%', '1,525,000', 'Seattle, Washington']
# ['3', 'Apple', 'Electronics industry', '383,482', '-2.8%', '161,000', 'Cupertino, California']
# ['4', 'UnitedHealth Group', 'Healthcare', '371,622', '14.6%', '440,000', 'Minnetonka, Minnesota']
# ['5', 'Berkshire Hathaway', 'Conglomerate', '364,482', '20.7%', '396,500', 'Omaha, Nebraska']
# ['6', 'CVS Health', 'Healthcare', '357,776', '10.9%', '259,500', 'Woonsocket, Rhode Island']
# ['7', 'ExxonMobil', 'Petroleum industry', '344,582', '-16.7%', '61,500', 'Spring, Texas']
# ['8', 'Alphabet', 'Technology and cloud computing', '307,394', '8.7%', '182,502', 'Mountain View, California']
# ['9', 'McKesson Corporation', 'Health', '276,711', '4.8%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '262,173', '9.9%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
length=len(df)
df=loc(length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 length=len(df)
# ----> 2 df=loc(length)
#
# NameError: name 'loc' is not defined

# %%
length=len(df)
df.loc[length]=finald

# %%
df
# Out:
#   Rank      Name Industry Revenue (USD millions) Revenue growth Employees  \
# 0  100  Best Buy   Retail                 43,452          -6.1%    85,000
#
#            Headquarters
# 0  Richfield, Minnesota

# %%
length=len(df)
df.loc[length]=finald
df
# Out:
#   Rank      Name Industry Revenue (USD millions) Revenue growth Employees  \
# 0  100  Best Buy   Retail                 43,452          -6.1%    85,000
# 1  100  Best Buy   Retail                 43,452          -6.1%    85,000
#
#            Headquarters
# 0  Richfield, Minnesota
# 1  Richfield, Minnesota

# %%
print(df)
# Out:
#   Rank      Name Industry Revenue (USD millions) Revenue growth Employees  \
# 0  100  Best Buy   Retail                 43,452          -6.1%    85,000
# 1  100  Best Buy   Retail                 43,452          -6.1%    85,000
#
#            Headquarters
# 0  Richfield, Minnesota
# 1  Richfield, Minnesota

# %%
for row in column_data[1:] :
    row_data=row.find_all('td')
    finald=[title.text.strip() for title in row_data]
    print(finald)
    length=len(df)
    df.loc[length]=finald
# Out:
# ['1', 'Walmart', 'Retail', '648,125', '6.0%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and cloud computing', '574,785', '11.9%', '1,525,000', 'Seattle, Washington']
# ['3', 'Apple', 'Electronics industry', '383,482', '-2.8%', '161,000', 'Cupertino, California']
# ['4', 'UnitedHealth Group', 'Healthcare', '371,622', '14.6%', '440,000', 'Minnetonka, Minnesota']
# ['5', 'Berkshire Hathaway', 'Conglomerate', '364,482', '20.7%', '396,500', 'Omaha, Nebraska']
# ['6', 'CVS Health', 'Healthcare', '357,776', '10.9%', '259,500', 'Woonsocket, Rhode Island']
# ['7', 'ExxonMobil', 'Petroleum industry', '344,582', '-16.7%', '61,500', 'Spring, Texas']
# ['8', 'Alphabet', 'Technology and cloud computing', '307,394', '8.7%', '182,502', 'Mountain View, California']
# ['9', 'McKesson Corporation', 'Health', '276,711', '4.8%', '48,000', 'Irving, Texas']
# ['10', 'Cencora', 'Pharmacy wholesale', '262,173', '9.9%', '44,000', 'Conshohocken, Pennsylvania']
# ...

# %%
df
# Out:
#     Rank                  Name                    Industry  \
# 0    100              Best Buy                      Retail
# 1    100              Best Buy                      Retail
# 2      1               Walmart                      Retail
# 3      2                Amazon  Retail and cloud computing
# 4      3                 Apple        Electronics industry
# ..   ...                   ...                         ...
# 97    96                  TIAA                  Financials
# 98    97                   CHS     Agriculture cooperative
# 99    98  Bristol-Myers Squibb     Pharmaceutical industry
# 100   99  Dow Chemical Company           Chemical industry
# 101  100              Best Buy                      Retail
#
#     Revenue (USD millions) Revenue growth  Employees  \
# 0                   43,452          -6.1%     85,000
# 1                   43,452          -6.1%     85,000
# 2                  648,125           6.0%  2,100,000
# ...

# %%
df.to_csv('C:\Users\Ali\OneDrive\Desktop\Data analysis Projects\Python Projects.csv',index=false)
# Out:
#   Cell In[59], line 1
#     df.to_csv('C:\Users\Ali\OneDrive\Desktop\Data analysis Projects\Python Projects.csv',index=false)
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.to_csv(r'C:\Users\Ali\OneDrive\Desktop\Data analysis Projects\Python Projects.csv',index = False)
